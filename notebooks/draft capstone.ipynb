# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import re 
import numpy as np

# %matplotlib inline

# %%
coffee_production_by_region = pd.read_csv('../data/coffee-production-by-region.csv')

# %%
coffee_production_by_region
# Out:
#         Entity Code  Year  \
# 0       Africa  NaN  1961
# 1       Africa  NaN  1962
# 2       Africa  NaN  1963
# 3       Africa  NaN  1964
# 4       Africa  NaN  1965
# ...        ...  ...   ...
# 7091  Zimbabwe  ZWE  2017
# 7092  Zimbabwe  ZWE  2018
# 7093  Zimbabwe  ZWE  2019
# 7094  Zimbabwe  ZWE  2020
# 7095  Zimbabwe  ZWE  2021
#
#       Coffee, green | 00000656 || Production | 005510 || tonnes
# 0                                             870970.00
# 1                                             883512.00
# 2                                             996674.00
# 3                                            1162048.00
# 4                                            1075084.00
# ...                                                 ...
# 7091                                             683.33
# 7092                                             627.78
# 7093                                             670.37
# 7094                                             660.49
# 7095                                             652.88
#
# [7096 rows x 4 columns]

# %%
coffee_production_by_region.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7096 entries, 0 to 7095
# Data columns (total 4 columns):
#  #   Column                                                     Non-Null Count  Dtype
# ---  ------                                                     --------------  -----
#  0   Entity                                                     7096 non-null   object
#  1   Code                                                       5080 non-null   object
#  2   Year                                                       7096 non-null   int64
#  3   Coffee, green | 00000656 || Production | 005510 || tonnes  7096 non-null   float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 221.9+ KB

# %%
coffee_production_by_region.isna().sum()
# Out:
# Entity                                                          0
# Code                                                         2016
# Year                                                            0
# Coffee, green | 00000656 || Production | 005510 || tonnes       0
# dtype: int64

# %%
coffee_production_by_region['Entity'].value_counts()
# Out:
# Entity
# Africa                       61
# Laos                         61
# Philippines                  61
# Peru                         61
# Paraguay                     61
#                              ..
# Nepal                        31
# Ethiopia                     29
# Europe (FAO)                 28
# Southern Europe (FAO)        28
# European Union (27) (FAO)    28
# Name: count, Length: 123, dtype: int64

# %%
coffee_production_by_region['Entity'].value_counts(dropna=False)
# Out:
# Entity
# Africa                       61
# Laos                         61
# Philippines                  61
# Peru                         61
# Paraguay                     61
#                              ..
# Nepal                        31
# Ethiopia                     29
# Europe (FAO)                 28
# Southern Europe (FAO)        28
# European Union (27) (FAO)    28
# Name: count, Length: 123, dtype: int64

# %%
coffee_production_by_region=coffee_production_by_region.rename(columns={'Coffee, green | 00000656 || Production | 005510 || tonnes':'Coffee,Green'})

# %%
coffee_production_by_region
# Out:
#         Entity Code  Year  Coffee,Green
# 0       Africa  NaN  1961     870970.00
# 1       Africa  NaN  1962     883512.00
# 2       Africa  NaN  1963     996674.00
# 3       Africa  NaN  1964    1162048.00
# 4       Africa  NaN  1965    1075084.00
# ...        ...  ...   ...           ...
# 7091  Zimbabwe  ZWE  2017        683.33
# 7092  Zimbabwe  ZWE  2018        627.78
# 7093  Zimbabwe  ZWE  2019        670.37
# 7094  Zimbabwe  ZWE  2020        660.49
# 7095  Zimbabwe  ZWE  2021        652.88
#
# [7096 rows x 4 columns]

# %%
coffee_production_by_region.groupby('Entity')['Coffee,Green'].describe()
# Out:
#                     count          mean           std        min  \
# Entity
# Africa               61.0  1.155357e+06  1.290412e+05   811188.4
# Africa (FAO)         61.0  1.155357e+06  1.290412e+05   811188.4
# Americas (FAO)       61.0  3.844193e+06  9.742367e+05  1905543.0
# Angola               61.0  5.972873e+04  8.483189e+04     1260.0
# Asia                 61.0  1.330636e+06  9.993853e+05   200714.0
# ...                   ...           ...           ...        ...
# Western Asia (FAO)   61.0  1.013004e+04  6.056384e+03     3970.0
# World                61.0  6.378561e+06  1.938520e+06  3522508.0
# Yemen                61.0  1.005858e+04  6.118994e+03     3810.0
# Zambia               56.0  2.794236e+03  2.770487e+03        0.0
# Zimbabwe             56.0  5.015942e+03  4.490884e+03       52.0
#
#                              25%         50%           75%          max
# Entity
# Africa              1.075084e+06  1165512.00  1.254209e+06   1431087.40
# Africa (FAO)        1.075084e+06  1165512.00  1.254209e+06   1431087.40
# Americas (FAO)      3.096048e+06  3752510.00  4.622290e+06   6090466.00
# Angola              5.000000e+03    12931.88  5.748000e+04    235200.00
# Asia                4.102800e+05   915561.00  2.219260e+06   3358628.20
# ...                          ...         ...           ...          ...
# Western Asia (FAO)  4.943000e+03     7411.00  1.729200e+04     21848.96
# World               4.725186e+06  6063096.00  7.930086e+06  10795444.00
# Yemen               4.823000e+03     7411.00  1.729200e+04     21848.96
# Zambia              4.750000e+01     1581.00  6.079257e+03      6708.90
# Zimbabwe            6.958325e+02     4155.00  9.150000e+03     14601.00
#
# [123 rows x 8 columns]

# %%
coffee_2010_2020=coffee_production_by_region.loc[(coffee_production_by_region['Year']>=2010) & (coffee_production_by_region['Year']<=2020)]

# %%
coffee_2010_2020
# Out:
#         Entity Code  Year  Coffee,Green
# 49      Africa  NaN  2010    1085218.60
# 50      Africa  NaN  2011     987478.40
# 51      Africa  NaN  2012     975107.44
# 52      Africa  NaN  2013    1104529.00
# 53      Africa  NaN  2014    1086611.50
# ...        ...  ...   ...           ...
# 7090  Zimbabwe  ZWE  2016        700.00
# 7091  Zimbabwe  ZWE  2017        683.33
# 7092  Zimbabwe  ZWE  2018        627.78
# 7093  Zimbabwe  ZWE  2019        670.37
# 7094  Zimbabwe  ZWE  2020        660.49
#
# [1267 rows x 4 columns]

# %%
coffee_2010_2020_region= coffee_2010_2020[coffee_2010_2020['Code'].isnull()]

# %%
coffee_2010_2020_region
# Out:
#                   Entity Code  Year  Coffee,Green
# 49                Africa  NaN  2010    1085218.60
# 50                Africa  NaN  2011     987478.40
# 51                Africa  NaN  2012     975107.44
# 52                Africa  NaN  2013    1104529.00
# 53                Africa  NaN  2014    1086611.50
# ...                  ...  ...   ...           ...
# 6856  Western Asia (FAO)  NaN  2016      18945.00
# 6857  Western Asia (FAO)  NaN  2017      18767.00
# 6858  Western Asia (FAO)  NaN  2018      18642.00
# 6859  Western Asia (FAO)  NaN  2019      20812.00
# 6860  Western Asia (FAO)  NaN  2020      21848.96
#
# [346 rows x 4 columns]

# %%
coffee_2010_2020['Coffee,Green'].value_counts().plot(kind = 'line');

# %%
print(coffee_2010_2020.dtypes)
# Out:
# Entity           object
# Code             object
# Year              int64
# Coffee,Green    float64
# dtype: object

# %%
coffee_production_region =coffee_2010_2020[coffee_2010_2020['Code'].isnull()]

# %%
agricultural_export_subsidies = pd.read_csv('../data/agricultural-export-subsidies.csv')

# %%
agricultural_export_subsidies
# Out:
#           Entity      Code  Year  \
# 0    Africa (UN)       NaN  1995
# 1    Africa (UN)       NaN  1996
# 2    Africa (UN)       NaN  1997
# 3    Africa (UN)       NaN  1998
# 4    Africa (UN)       NaN  1999
# ..           ...       ...   ...
# 969        World  OWID_WRL  2017
# 970        World  OWID_WRL  2018
# 971        World  OWID_WRL  2019
# 972        World  OWID_WRL  2020
# 973        World  OWID_WRL  2021
#
#      2.b.1 - Agricultural export subsidies (millions of current United States dollars) - AG_PRD_XSUBDY
# 0                                           40660000.0
# 1                                           43500000.0
# 2                                           24290000.0
# 3                                            9960000.0
# 4                                           10930000.0
# ..                                                 ...
# 969                                        197800000.0
# 970                                        185730000.0
# 971                                         77510000.0
# 972                                         11660000.0
# 973                                                0.0
#
# [974 rows x 4 columns]

# %%
agricultural_export_subsidies.isna().sum()
# Out:
# Entity                                                                                                 0
# Code                                                                                                 331
# Year                                                                                                   0
# 2.b.1 - Agricultural export subsidies (millions of current United States dollars) - AG_PRD_XSUBDY      0
# dtype: int64

# %% [markdown]
# agricultural_export_subsidies=agricultural_export_subsidies.drop('Code', axis=1)

# %%
agricultural_export_subsidies
# Out:
#           Entity      Code  Year  \
# 0    Africa (UN)       NaN  1995
# 1    Africa (UN)       NaN  1996
# 2    Africa (UN)       NaN  1997
# 3    Africa (UN)       NaN  1998
# 4    Africa (UN)       NaN  1999
# ..           ...       ...   ...
# 969        World  OWID_WRL  2017
# 970        World  OWID_WRL  2018
# 971        World  OWID_WRL  2019
# 972        World  OWID_WRL  2020
# 973        World  OWID_WRL  2021
#
#      2.b.1 - Agricultural export subsidies (millions of current United States dollars) - AG_PRD_XSUBDY
# 0                                           40660000.0
# 1                                           43500000.0
# 2                                           24290000.0
# 3                                            9960000.0
# 4                                           10930000.0
# ..                                                 ...
# 969                                        197800000.0
# 970                                        185730000.0
# 971                                         77510000.0
# 972                                         11660000.0
# 973                                                0.0
#
# [974 rows x 4 columns]

# %%
agricultural_export_2010_2020=agricultural_export_subsidies.loc[(agricultural_export_subsidies['Year']>=2010) & (agricultural_export_subsidies['Year']<=2020)]

# %%
agricultural_export_2010_2020
# Out:
#           Entity      Code  Year  \
# 15   Africa (UN)       NaN  2010
# 16   Africa (UN)       NaN  2011
# 17   Africa (UN)       NaN  2012
# 18   Africa (UN)       NaN  2013
# 19   Africa (UN)       NaN  2014
# ..           ...       ...   ...
# 968        World  OWID_WRL  2016
# 969        World  OWID_WRL  2017
# 970        World  OWID_WRL  2018
# 971        World  OWID_WRL  2019
# 972        World  OWID_WRL  2020
#
#      2.b.1 - Agricultural export subsidies (millions of current United States dollars) - AG_PRD_XSUBDY
# 15                                           7650000.0
# 16                                          16460000.0
# 17                                          12720000.0
# 18                                           7980000.0
# 19                                          18250000.0
# ..                                                 ...
# 968                                        209640000.0
# 969                                        197800000.0
# 970                                        185730000.0
# 971                                         77510000.0
# 972                                         11660000.0
#
# [338 rows x 4 columns]

# %%
print(agricultural_export_2010_2020.dtypes)
# Out:
# Entity                                                                                                object
# Code                                                                                                  object
# Year                                                                                                   int64
# 2.b.1 - Agricultural export subsidies (millions of current United States dollars) - AG_PRD_XSUBDY    float64
# dtype: object

# %%
agricultural_export_2010_2020_region=agricultural_export_2010_2020[agricultural_export_2010_2020['Code'].isnull()]

# %%
agricultural_export_2010_2020_region
# Out:
#                       Entity Code  Year  \
# 15               Africa (UN)  NaN  2010
# 16               Africa (UN)  NaN  2011
# 17               Africa (UN)  NaN  2012
# 18               Africa (UN)  NaN  2013
# 19               Africa (UN)  NaN  2014
# ..                       ...  ...   ...
# 798  Sub-Saharan Africa (UN)  NaN  2016
# 799  Sub-Saharan Africa (UN)  NaN  2017
# 800  Sub-Saharan Africa (UN)  NaN  2018
# 801  Sub-Saharan Africa (UN)  NaN  2019
# 802  Sub-Saharan Africa (UN)  NaN  2020
#
#      2.b.1 - Agricultural export subsidies (millions of current United States dollars) - AG_PRD_XSUBDY
# 15                                           7650000.0
# 16                                          16460000.0
# 17                                          12720000.0
# 18                                           7980000.0
# 19                                          18250000.0
# ..                                                 ...
# 798                                           700000.0
# 799                                           150000.0
# 800                                           150000.0
# 801                                            60000.0
# 802                                            10000.0
#
# [133 rows x 4 columns]

# %%
agricultural_area_per_capita = pd.read_csv('../data/agricultural-area-per-capita.csv')

# %%
agricultural_area_per_capita
# Out:
#             Entity Code  Year  \
# 0      Afghanistan  AFG  1961
# 1      Afghanistan  AFG  1962
# 2      Afghanistan  AFG  1963
# 3      Afghanistan  AFG  1964
# 4      Afghanistan  AFG  1965
# ...            ...  ...   ...
# 13253     Zimbabwe  ZWE  2016
# 13254     Zimbabwe  ZWE  2017
# 13255     Zimbabwe  ZWE  2018
# 13256     Zimbabwe  ZWE  2019
# 13257     Zimbabwe  ZWE  2020
#
#        Agricultural land | 00006610 || Area | 5110pc || hectares per capita
# 0                                               4.288897
# 1                                               4.210031
# 2                                               4.128873
# 3                                               4.048203
# 4                                               3.959685
# ...                                                  ...
# 13253                                           1.120897
# 13254                                           1.098223
# 13255                                           1.076255
# 13256                                           1.055058
# 13257                                           1.033845
#
# [13258 rows x 4 columns]

# %%
agricultural_area_per_capita=agricultural_area_per_capita.rename(columns={'Agricultural land | 00006610 || Area | 5110pc || hectares per capita':'Agricultural land hectares per capita'})

# %% [markdown]
# agricultural_area_per_capita=agricultural_area_per_capita.drop('Code', axis=1)

# %%
agricultural_area_2010_2020=agricultural_area_per_capita.loc[(agricultural_area_per_capita['Year']>=2010) & (agricultural_area_per_capita['Year']<=2020)]

# %%
print(agricultural_area_2010_2020.dtypes)
# Out:
# Entity                                    object
# Code                                      object
# Year                                       int64
# Agricultural land hectares per capita    float64
# dtype: object

# %%
agricultural_area_2010_2020_region=agricultural_area_2010_2020[agricultural_area_2010_2020['Code'].isnull()]

# %%
agricultural_area_2010_2020_region
# Out:
#                               Entity Code  Year  \
# 109                           Africa  NaN  2010
# 110                           Africa  NaN  2011
# 111                           Africa  NaN  2012
# 112                           Africa  NaN  2013
# 113                           Africa  NaN  2014
# ...                              ...  ...   ...
# 12593  Upper-middle-income countries  NaN  2016
# 12594  Upper-middle-income countries  NaN  2017
# 12595  Upper-middle-income countries  NaN  2018
# 12596  Upper-middle-income countries  NaN  2019
# 12597  Upper-middle-income countries  NaN  2020
#
#        Agricultural land hectares per capita
# 109                                 0.990905
# 110                                 0.969465
# 111                                 0.996507
# 112                                 0.974610
# 113                                 0.951014
# ...                                      ...
# 12593                               0.748835
# 12594                               0.743871
# 12595                               0.737719
# 12596                               0.732815
# 12597                               0.729497
#
# [123 rows x 4 columns]

# %% [markdown]
# coffee_2010_2020_region , agricultural_export_2010_2020_region, agricultural_area_2010_2020_region

# %%
coffee_2010_2020_region_export =pd.merge(agricultural_export_2010_2020_region,coffee_2010_2020_region, left_on= 'Year',right_on='Year',how='inner')

# %%
coffee_2010_2020_region_export
# Out:
#                      Entity_x Code_x  Year  \
# 0                 Africa (UN)    NaN  2010
# 1                 Africa (UN)    NaN  2010
# 2                 Africa (UN)    NaN  2010
# 3                 Africa (UN)    NaN  2010
# 4                 Africa (UN)    NaN  2010
# ...                       ...    ...   ...
# 4183  Sub-Saharan Africa (UN)    NaN  2020
# 4184  Sub-Saharan Africa (UN)    NaN  2020
# 4185  Sub-Saharan Africa (UN)    NaN  2020
# 4186  Sub-Saharan Africa (UN)    NaN  2020
# 4187  Sub-Saharan Africa (UN)    NaN  2020
#
#       2.b.1 - Agricultural export subsidies (millions of current United States dollars) - AG_PRD_XSUBDY  \
# 0                                             7650000.0
# 1                                             7650000.0
# 2                                             7650000.0
# 3                                             7650000.0
# 4                                             7650000.0
# ...                                                 ...
# 4183                                            10000.0
# 4184                                            10000.0
# 4185                                            10000.0
# 4186                                            10000.0
# 4187                                            10000.0
#
#                            Entity_y Code_y  Coffee,Green
# 0                            Africa    NaN    1085218.60
# 1                      Africa (FAO)    NaN    1085218.60
# 2                    Americas (FAO)    NaN    4960499.00
# 3                              Asia    NaN    2379412.20
# 4                        Asia (FAO)    NaN    2379412.20
# ...                             ...    ...           ...
# 4183       South-eastern Asia (FAO)    NaN    2791449.00
# 4184            Southern Asia (FAO)    NaN     305021.60
# 4185  Upper-middle-income countries    NaN    5572097.00
# 4186           Western Africa (FAO)    NaN     169713.88
# 4187             Western Asia (FAO)    NaN      21848.96
#
# [4188 rows x 7 columns]

# %%
coffee_2010_2020_region_export=coffee_2010_2020_region_export.drop('Entity_x', axis =1)

# %%
coffee_2010_2020_region_export=coffee_2010_2020_region_export.drop('Code_x',axis=1)

# %%
coffee_2010_2020_region_export=coffee_2010_2020_region_export.rename(columns={'2.b.1 - Agricultural export subsidies (millions of current United States dollars) - AG_PRD_XSUBDY':'Agricultural export $'})

# %%
coffee_2010_2020_region_export
# Out:
#       Year  Agricultural export $                       Entity_y Code_y  \
# 0     2010              7650000.0                         Africa    NaN
# 1     2010              7650000.0                   Africa (FAO)    NaN
# 2     2010              7650000.0                 Americas (FAO)    NaN
# 3     2010              7650000.0                           Asia    NaN
# 4     2010              7650000.0                     Asia (FAO)    NaN
# ...    ...                    ...                            ...    ...
# 4183  2020                10000.0       South-eastern Asia (FAO)    NaN
# 4184  2020                10000.0            Southern Asia (FAO)    NaN
# 4185  2020                10000.0  Upper-middle-income countries    NaN
# 4186  2020                10000.0           Western Africa (FAO)    NaN
# 4187  2020                10000.0             Western Asia (FAO)    NaN
#
#       Coffee,Green
# 0       1085218.60
# 1       1085218.60
# 2       4960499.00
# 3       2379412.20
# 4       2379412.20
# ...            ...
# 4183    2791449.00
# 4184     305021.60
# 4185    5572097.00
# 4186     169713.88
# 4187      21848.96
#
# [4188 rows x 5 columns]

# %%
coffee_2010_2020_region_area =pd.merge(agricultural_area_2010_2020_region,coffee_2010_2020_region, left_on= 'Year',right_on='Year',how='inner')

# %%
coffee_2010_2020_region_area
# Out:
#                            Entity_x Code_x  Year  \
# 0                            Africa    NaN  2010
# 1                            Africa    NaN  2010
# 2                            Africa    NaN  2010
# 3                            Africa    NaN  2010
# 4                            Africa    NaN  2010
# ...                             ...    ...   ...
# 3865  Upper-middle-income countries    NaN  2020
# 3866  Upper-middle-income countries    NaN  2020
# 3867  Upper-middle-income countries    NaN  2020
# 3868  Upper-middle-income countries    NaN  2020
# 3869  Upper-middle-income countries    NaN  2020
#
#       Agricultural land hectares per capita                       Entity_y  \
# 0                                  0.990905                         Africa
# 1                                  0.990905                   Africa (FAO)
# 2                                  0.990905                 Americas (FAO)
# 3                                  0.990905                           Asia
# 4                                  0.990905                     Asia (FAO)
# ...                                     ...                            ...
# 3865                               0.729497       South-eastern Asia (FAO)
# 3866                               0.729497            Southern Asia (FAO)
# 3867                               0.729497  Upper-middle-income countries
# 3868                               0.729497           Western Africa (FAO)
# 3869                               0.729497             Western Asia (FAO)
#
#      Code_y  Coffee,Green
# 0       NaN    1085218.60
# 1       NaN    1085218.60
# 2       NaN    4960499.00
# 3       NaN    2379412.20
# 4       NaN    2379412.20
# ...     ...           ...
# 3865    NaN    2791449.00
# 3866    NaN     305021.60
# 3867    NaN    5572097.00
# 3868    NaN     169713.88
# 3869    NaN      21848.96
#
# [3870 rows x 7 columns]

# %%
coffee_2010_2020_region_area=coffee_2010_2020_region_area.drop('Entity_x',axis=1)

# %%
coffee_2010_2020_region_area=coffee_2010_2020_region_area.drop('Code_x',axis=1)

# %%
coffee_2010_2020_region_area
# Out:
#       Year  Agricultural land hectares per capita  \
# 0     2010                               0.990905
# 1     2010                               0.990905
# 2     2010                               0.990905
# 3     2010                               0.990905
# 4     2010                               0.990905
# ...    ...                                    ...
# 3865  2020                               0.729497
# 3866  2020                               0.729497
# 3867  2020                               0.729497
# 3868  2020                               0.729497
# 3869  2020                               0.729497
#
#                            Entity_y Code_y  Coffee,Green
# 0                            Africa    NaN    1085218.60
# 1                      Africa (FAO)    NaN    1085218.60
# 2                    Americas (FAO)    NaN    4960499.00
# 3                              Asia    NaN    2379412.20
# 4                        Asia (FAO)    NaN    2379412.20
# ...                             ...    ...           ...
# 3865       South-eastern Asia (FAO)    NaN    2791449.00
# 3866            Southern Asia (FAO)    NaN     305021.60
# 3867  Upper-middle-income countries    NaN    5572097.00
# 3868           Western Africa (FAO)    NaN     169713.88
# 3869             Western Asia (FAO)    NaN      21848.96
#
# [3870 rows x 5 columns]

# %%
coffee_2010_2020_region_export
# Out:
#       Year  Agricultural export $                       Entity_y Code_y  \
# 0     2010              7650000.0                         Africa    NaN
# 1     2010              7650000.0                   Africa (FAO)    NaN
# 2     2010              7650000.0                 Americas (FAO)    NaN
# 3     2010              7650000.0                           Asia    NaN
# 4     2010              7650000.0                     Asia (FAO)    NaN
# ...    ...                    ...                            ...    ...
# 4183  2020                10000.0       South-eastern Asia (FAO)    NaN
# 4184  2020                10000.0            Southern Asia (FAO)    NaN
# 4185  2020                10000.0  Upper-middle-income countries    NaN
# 4186  2020                10000.0           Western Africa (FAO)    NaN
# 4187  2020                10000.0             Western Asia (FAO)    NaN
#
#       Coffee,Green
# 0       1085218.60
# 1       1085218.60
# 2       4960499.00
# 3       2379412.20
# 4       2379412.20
# ...            ...
# 4183    2791449.00
# 4184     305021.60
# 4185    5572097.00
# 4186     169713.88
# 4187      21848.96
#
# [4188 rows x 5 columns]

# %% [markdown]
# 1,How does the amount of agricultural export subsidies affect coffee production in different regions over time?

# %%
print(coffee_2010_2020_region_export.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4188 entries, 0 to 4187
# Data columns (total 5 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Year                   4188 non-null   int64
#  1   Agricultural export $  4188 non-null   float64
#  2   Entity_y               4188 non-null   object
#  3   Code_y                 0 non-null      object
#  4   Coffee,Green           4188 non-null   float64
# dtypes: float64(2), int64(1), object(2)
# memory usage: 163.7+ KB
# None

# %%
print(coffee_2010_2020_region_export.isnull().sum())
#no null values to drop, the code_y is null becuse regions dont have code countries do, and for this question we are looking at regions
# Out:
# Year                        0
# Agricultural export $       0
# Entity_y                    0
# Code_y                   4188
# Coffee,Green                0
# dtype: int64

# %%
grouped_data = coffee_2010_2020_region_export.groupby(['Entity_y', 'Year']).sum()
grouped_data=grouped_data.reset_index()

# %%
relation_export_coffee_production = grouped_data.drop('Code_y', axis=1)

# %%
relation_export_coffee_production
# Out:
#                Entity_y  Year  Agricultural export $  Coffee,Green
# 0                Africa  2010           1.074590e+09   13022623.20
# 1                Africa  2011           1.085920e+09   11849740.80
# 2                Africa  2012           7.965500e+08   11701289.28
# 3                Africa  2013           5.855700e+08   14358877.00
# 4                Africa  2014           5.083200e+08   14125949.50
# ..                  ...   ...                    ...           ...
# 341  Western Asia (FAO)  2016           4.705300e+08     227340.00
# 342  Western Asia (FAO)  2017           4.487500e+08     225204.00
# 343  Western Asia (FAO)  2018           4.194300e+08     223704.00
# 344  Western Asia (FAO)  2019           2.090000e+08     249744.00
# 345  Western Asia (FAO)  2020           2.332000e+07     218489.60
#
# [346 rows x 4 columns]

# %%
relation_export_coffee_production.rename(columns={'Entity_y':'Region'})
# Out:
#                  Region  Year  Agricultural export $  Coffee,Green
# 0                Africa  2010           1.074590e+09   13022623.20
# 1                Africa  2011           1.085920e+09   11849740.80
# 2                Africa  2012           7.965500e+08   11701289.28
# 3                Africa  2013           5.855700e+08   14358877.00
# 4                Africa  2014           5.083200e+08   14125949.50
# ..                  ...   ...                    ...           ...
# 341  Western Asia (FAO)  2016           4.705300e+08     227340.00
# 342  Western Asia (FAO)  2017           4.487500e+08     225204.00
# 343  Western Asia (FAO)  2018           4.194300e+08     223704.00
# 344  Western Asia (FAO)  2019           2.090000e+08     249744.00
# 345  Western Asia (FAO)  2020           2.332000e+07     218489.60
#
# [346 rows x 4 columns]

# %%
relation_export_coffee_production.to_csv('sample.csv')

# %%
relation_export_coffee_production.to_excel('relation_export_coffee_production.xlsx')

# %%
relation_export_coffee_production['Agricultural export $'].hist();

# %% [markdown]
# 2,How does the amount of agricultural land per capita affect coffee production in different regions?

# %%
coffee_2010_2020_region_area
# Out:
#       Year  Agricultural land hectares per capita  \
# 0     2010                               0.990905
# 1     2010                               0.990905
# 2     2010                               0.990905
# 3     2010                               0.990905
# 4     2010                               0.990905
# ...    ...                                    ...
# 3865  2020                               0.729497
# 3866  2020                               0.729497
# 3867  2020                               0.729497
# 3868  2020                               0.729497
# 3869  2020                               0.729497
#
#                            Entity_y Code_y  Coffee,Green
# 0                            Africa    NaN    1085218.60
# 1                      Africa (FAO)    NaN    1085218.60
# 2                    Americas (FAO)    NaN    4960499.00
# 3                              Asia    NaN    2379412.20
# 4                        Asia (FAO)    NaN    2379412.20
# ...                             ...    ...           ...
# 3865       South-eastern Asia (FAO)    NaN    2791449.00
# 3866            Southern Asia (FAO)    NaN     305021.60
# 3867  Upper-middle-income countries    NaN    5572097.00
# 3868           Western Africa (FAO)    NaN     169713.88
# 3869             Western Asia (FAO)    NaN      21848.96
#
# [3870 rows x 5 columns]

# %%
grouped_data_area = coffee_2010_2020_region_area.groupby(['Entity_y', 'Year']).sum()
grouped_data_area=grouped_data_area.reset_index()

# %%
grouped_data_area
# Out:
#                Entity_y  Year  Agricultural land hectares per capita Code_y  \
# 0                Africa  2010                              21.949675      0
# 1                Africa  2011                              22.116126      0
# 2                Africa  2012                              18.482575      0
# 3                Africa  2013                              17.805802      0
# 4                Africa  2014                              17.596889      0
# ..                  ...   ...                                    ...    ...
# 341  Western Asia (FAO)  2016                              16.267437      0
# 342  Western Asia (FAO)  2017                              16.766071      0
# 343  Western Asia (FAO)  2018                              16.197644      0
# 344  Western Asia (FAO)  2019                              16.051524      0
# 345  Western Asia (FAO)  2020                              15.681227      0
#
#      Coffee,Green
# 0     13022623.20
# 1     11849740.80
# 2     10726181.84
# 3     12149819.00
# 4     11952726.50
# ..            ...
# 341     208395.00
# 342     206437.00
# 343     205062.00
# 344     228932.00
# 345     240338.56
#
# [346 rows x 5 columns]

# %%
relation_area_coffee_production = grouped_data_area.drop('Code_y', axis=1)

# %%
relation_area_coffee_production=relation_area_coffee_production.rename(columns={'Entity_y':'Region'})

# %%
relation_area_coffee_production
# Out:
#                  Region  Year  Agricultural land hectares per capita  \
# 0                Africa  2010                              21.949675
# 1                Africa  2011                              22.116126
# 2                Africa  2012                              18.482575
# 3                Africa  2013                              17.805802
# 4                Africa  2014                              17.596889
# ..                  ...   ...                                    ...
# 341  Western Asia (FAO)  2016                              16.267437
# 342  Western Asia (FAO)  2017                              16.766071
# 343  Western Asia (FAO)  2018                              16.197644
# 344  Western Asia (FAO)  2019                              16.051524
# 345  Western Asia (FAO)  2020                              15.681227
#
#      Coffee,Green
# 0     13022623.20
# 1     11849740.80
# 2     10726181.84
# 3     12149819.00
# 4     11952726.50
# ..            ...
# 341     208395.00
# 342     206437.00
# 343     205062.00
# 344     228932.00
# 345     240338.56
#
# [346 rows x 4 columns]

# %%
relation_area_coffee_production.to_excel('relation_area_coffee_production.xlsx')

# %% [markdown]
# 3, What is the relationship between coffee production and economic development?

# %%
World_economic = pd.read_excel('../data/world_eco.xlsx')

# %%
World_economic
# Out:
#                                         Economy Code  \
# 0                                         Aruba  ABW
# 1                                   Afghanistan  AFG
# 2                                        Angola  AGO
# 3                                       Albania  ALB
# 4                                       Andorra  AND
# ..                                          ...  ...
# 262                          Sub-Saharan Africa  SSF
# 263  Sub-Saharan Africa (excluding high income)  SSA
# 264             Sub-Saharan Africa (IDA & IBRD)  TSS
# 265                         Upper middle income  UMC
# 266                                       World  WLD
#
#                         Region         Income group Lending category
# 0    Latin America & Caribbean          High income              NaN
# 1                   South Asia           Low income              IDA
# 2           Sub-Saharan Africa  Lower middle income             IBRD
# 3        Europe & Central Asia  Upper middle income             IBRD
# 4        Europe & Central Asia          High income              NaN
# ..                         ...                  ...              ...
# 262                        NaN                  NaN              NaN
# 263                        NaN                  NaN              NaN
# 264                        NaN                  NaN              NaN
# 265                        NaN                  NaN              NaN
# 266                        NaN                  NaN              NaN
#
# [267 rows x 5 columns]

# %%
coffee_production_country = coffee_production_by_region.dropna(subset=['Code'])

# %%
coffee_economic_country =pd.merge(coffee_production_country,World_economic, left_on= 'Code',right_on='Code',how='inner')

# %%
coffee_economic_country
# Out:
#         Entity Code  Year  Coffee,Green   Economy              Region  \
# 0       Angola  AGO  1961     168600.00    Angola  Sub-Saharan Africa
# 1       Angola  AGO  1962     185000.00    Angola  Sub-Saharan Africa
# 2       Angola  AGO  1963     168300.00    Angola  Sub-Saharan Africa
# 3       Angola  AGO  1964     198200.00    Angola  Sub-Saharan Africa
# 4       Angola  AGO  1965     205000.00    Angola  Sub-Saharan Africa
# ...        ...  ...   ...           ...       ...                 ...
# 4721  Zimbabwe  ZWE  2017        683.33  Zimbabwe  Sub-Saharan Africa
# 4722  Zimbabwe  ZWE  2018        627.78  Zimbabwe  Sub-Saharan Africa
# 4723  Zimbabwe  ZWE  2019        670.37  Zimbabwe  Sub-Saharan Africa
# 4724  Zimbabwe  ZWE  2020        660.49  Zimbabwe  Sub-Saharan Africa
# 4725  Zimbabwe  ZWE  2021        652.88  Zimbabwe  Sub-Saharan Africa
#
#              Income group Lending category
# 0     Lower middle income             IBRD
# 1     Lower middle income             IBRD
# 2     Lower middle income             IBRD
# 3     Lower middle income             IBRD
# 4     Lower middle income             IBRD
# ...                   ...              ...
# 4721  Lower middle income            Blend
# 4722  Lower middle income            Blend
# 4723  Lower middle income            Blend
# 4724  Lower middle income            Blend
# 4725  Lower middle income            Blend
#
# [4726 rows x 8 columns]

# %%
coffee_economic_country=coffee_economic_country.drop('Entity',axis=1)

# %%
coffee_economic_country
# Out:
#      Code  Year  Coffee,Green   Economy              Region  \
# 0     AGO  1961     168600.00    Angola  Sub-Saharan Africa
# 1     AGO  1962     185000.00    Angola  Sub-Saharan Africa
# 2     AGO  1963     168300.00    Angola  Sub-Saharan Africa
# 3     AGO  1964     198200.00    Angola  Sub-Saharan Africa
# 4     AGO  1965     205000.00    Angola  Sub-Saharan Africa
# ...   ...   ...           ...       ...                 ...
# 4721  ZWE  2017        683.33  Zimbabwe  Sub-Saharan Africa
# 4722  ZWE  2018        627.78  Zimbabwe  Sub-Saharan Africa
# 4723  ZWE  2019        670.37  Zimbabwe  Sub-Saharan Africa
# 4724  ZWE  2020        660.49  Zimbabwe  Sub-Saharan Africa
# 4725  ZWE  2021        652.88  Zimbabwe  Sub-Saharan Africa
#
#              Income group Lending category
# 0     Lower middle income             IBRD
# 1     Lower middle income             IBRD
# 2     Lower middle income             IBRD
# 3     Lower middle income             IBRD
# 4     Lower middle income             IBRD
# ...                   ...              ...
# 4721  Lower middle income            Blend
# 4722  Lower middle income            Blend
# 4723  Lower middle income            Blend
# 4724  Lower middle income            Blend
# 4725  Lower middle income            Blend
#
# [4726 rows x 7 columns]

# %%
coffee_economic_country=coffee_economic_country.loc[(coffee_economic_country['Year']>=2010) & (coffee_economic_country['Year']<=2020)]

# %%
coffee_economic_country
# Out:
#      Code  Year  Coffee,Green   Economy              Region  \
# 49    AGO  2010       9951.00    Angola  Sub-Saharan Africa
# 50    AGO  2011      10192.00    Angola  Sub-Saharan Africa
# 51    AGO  2012      11740.03    Angola  Sub-Saharan Africa
# 52    AGO  2013      12550.00    Angola  Sub-Saharan Africa
# 53    AGO  2014      15009.00    Angola  Sub-Saharan Africa
# ...   ...   ...           ...       ...                 ...
# 4720  ZWE  2016        700.00  Zimbabwe  Sub-Saharan Africa
# 4721  ZWE  2017        683.33  Zimbabwe  Sub-Saharan Africa
# 4722  ZWE  2018        627.78  Zimbabwe  Sub-Saharan Africa
# 4723  ZWE  2019        670.37  Zimbabwe  Sub-Saharan Africa
# 4724  ZWE  2020        660.49  Zimbabwe  Sub-Saharan Africa
#
#              Income group Lending category
# 49    Lower middle income             IBRD
# 50    Lower middle income             IBRD
# 51    Lower middle income             IBRD
# 52    Lower middle income             IBRD
# 53    Lower middle income             IBRD
# ...                   ...              ...
# 4720  Lower middle income            Blend
# 4721  Lower middle income            Blend
# 4722  Lower middle income            Blend
# 4723  Lower middle income            Blend
# 4724  Lower middle income            Blend
#
# [877 rows x 7 columns]

# %%
coffee_economic_country_grouped = coffee_economic_country.groupby(['Income group', 'Year']).sum()

# %%
coffee_economic_country_grouped
# Out:
#                                                                        Code  \
# Income group        Year
# High income         2010                        PYFGUYNCLPANPRIESPTWNTTOUSA
#                     2011                        PYFGUYNCLPANPRIESPTWNTTOUSA
#                     2012                        PYFGUYNCLPANPRIESPTWNTTOUSA
#                     2013                        PYFGUYNCLPANPRIESPTWNTTOUSA
#                     2014                        PYFGUYNCLPANPRIESPTWNTTOUSA
#                     2015                        PYFGUYNCLPANPRIESPTWNTTOUSA
#                     2016                        PYFGUYNCLPANPRIESPTWNTTOUSA
#                     2017                        PYFGUYNCLPANPRIESPTWNTTOUSA
#                     2018                           PYFGUYNCLPANPRITWNTTOUSA
#                     2019                           PYFGUYNCLPANPRITWNTTOUSA
#                     2020                           PYFGUYNCLPANPRITWNTTOUSA
# Low income          2010            BDICAFCODETHLBRMDGMWIMOZRWASLETGOUGAYEM
#                     2011            BDICAFCODETHLBRMDGMWIMOZRWASLETGOUGAYEM
#                     2017  IBRDIBRDIBRDIBRDIBRDBlendIBRDIBRDIBRDIBRDBlend...
#                     2018  IBRDIBRDIBRDIBRDIBRDBlendIBRDIBRDIBRDIBRDBlend...
#                     2019  IBRDIBRDIBRDIBRDIBRDBlendIBRDIBRDIBRDIBRDBlend...
#                     2020  IBRDIBRDIBRDIBRDIBRDBlendIBRDIBRDIBRDIBRDBlend...

# %%
plt.figure(figsize = (10,6))

sns.scatterplot(data = coffee_economic_country ,
               x = 'Year',
               y = 'Coffee,Green',
               hue = 'Income group',
               palette = ['cornflowerblue', 'coral', 'pink']);
# Out:
# C:\Users\willi\AppData\Local\Temp\ipykernel_10740\413440779.py:3: UserWarning:
# The palette list has fewer values (3) than needed (4) and will cycle, which may produce an uninterpretable plot.
#   sns.scatterplot(data = coffee_economic_country ,

# %%
correlation = coffee_economic_country ['Income group'].corr(coffee_economic_country ['Coffee,Green'])
#print(f"Correlation between Economic Development and Coffee Production: {correlation}")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[100], line 1
# ----> 1 correlation = coffee_economic_country ['Income group'].corr(coffee_economic_country ['Coffee,Green'])
#
# File ~\anaconda3\Lib\site-packages\pandas\core\series.py:2727, in Series.corr(self, other, method, min_periods)
#    2724     return np.nan
#    2726 if method in ["pearson", "spearman", "kendall"] or callable(method):
# -> 2727     return nanops.nancorr(
#    2728         this.values, other.values, method=method, min_periods=min_periods
#    2729     )
#    2731 raise ValueError(
#    2732     "method must be either 'pearson', "
#    2733     "'spearman', 'kendall', or a callable, "
#    2734     f"'{method}' was supplied"
#    2735 )
#
# File ~\anaconda3\Lib\site-packages\pandas\core\nanops.py:96, in disallow.__call__.<locals>._f(*args, **kwargs)
#      94 try:
#      95     with np.errstate(invalid="ignore"):
# ---> 96         return f(*args, **kwargs)
#      97 except ValueError as e:
#      98     # we want to transform an object array
#      99     # ValueError message to the more typical TypeError
#     100     # e.g. this is normally a disallowed function on
#     101     # object arrays that contain strings
#     102     if is_object_dtype(args[0]):
#
# File ~\anaconda3\Lib\site-packages\pandas\core\nanops.py:1614, in nancorr(a, b, method, min_periods)
#    1611     return np.nan
#    1613 f = get_corr_func(method)
# -> 1614 return f(a, b)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\nanops.py:1637, in get_corr_func.<locals>.func(a, b)
#    1636 def func(a, b):
# -> 1637     return np.corrcoef(a, b)[0, 1]
#
# File <__array_function__ internals>:200, in corrcoef(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\numpy\lib\function_base.py:2846, in corrcoef(x, y, rowvar, bias, ddof, dtype)
#    2842 if bias is not np._NoValue or ddof is not np._NoValue:
#    2843     # 2015-03-15, 1.10
#    2844     warnings.warn('bias and ddof have no effect and are deprecated',
#    2845                   DeprecationWarning, stacklevel=3)
# -> 2846 c = cov(x, y, rowvar, dtype=dtype)
#    2847 try:
#    2848     d = diag(c)
#
# File <__array_function__ internals>:200, in cov(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\numpy\lib\function_base.py:2681, in cov(m, y, rowvar, bias, ddof, fweights, aweights, dtype)
#    2678     else:
#    2679         w *= aweights
# -> 2681 avg, w_sum = average(X, axis=1, weights=w, returned=True)
#    2682 w_sum = w_sum[0]
#    2684 # Determine the normalization
#
# File <__array_function__ internals>:200, in average(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\numpy\lib\function_base.py:518, in average(a, axis, weights, returned, keepdims)
#     515     keepdims_kw = {'keepdims': keepdims}
#     517 if weights is None:
# --> 518     avg = a.mean(axis, **keepdims_kw)
#     519     avg_as_array = np.asanyarray(avg)
#     520     scl = avg_as_array.dtype.type(a.size/avg_as_array.size)
#
# File ~\anaconda3\Lib\site-packages\numpy\core\_methods.py:184, in _mean(a, axis, dtype, out, keepdims, where)
#     182 if isinstance(ret, mu.ndarray):
#     183     with _no_nep50_warning():
# --> 184         ret = um.true_divide(
#     185                 ret, rcount, out=ret, casting='unsafe', subok=False)
#     186     if is_float16_result and out is None:
#     187         ret = arr.dtype.type(ret)
#
# TypeError: unsupported operand type(s) for /: 'str' and 'int'

# %% [markdown]
# country= pd.read_csv('../data/country.csv',skiprows=4)

# %% [markdown]
# country
